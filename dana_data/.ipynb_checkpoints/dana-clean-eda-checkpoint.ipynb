# %%
import pandas as pd
import numpy as np

# %%
abilene = pd.read_csv('./Abilene_data.csv')
amarillo = pd.read_csv('./Amarillo_data.csv')
elpaso = pd.read_csv('./El_Paso_data.csv')
laredo = pd.read_csv('./Laredo_data.csv')
lubbock = pd.read_csv('./Lubbock_data.csv')
odessa = pd.read_csv('./Odessa_data.csv')

# %%
dfs = [elpaso, lubbock, amarillo, laredo, odessa, abilene]
for df in dfs:
    #df.drop(columns='Unnamed: 0', inplace=True)
    print(df.shape)
    print(df.dtypes)
    print(df.isnull().sum())
    print()
# Out:
# (13862, 10)
# Unnamed: 0      int64
# id              int64
# text           object
# date           object
# retweets        int64
# favorites       int64
# mentions       object
# hashtags       object
# geo           float64
# region         object
# dtype: object
# Unnamed: 0        0
# id                0
# text            445
# date              0
# retweets          0
# favorites         0
# mentions      12408
# hashtags      12613
# geo           13862
# region            0
# dtype: int64
#
# (6767, 10)
# Unnamed: 0      int64
# id              int64
# text           object
# date           object
# retweets        int64
# favorites       int64
# mentions       object
# hashtags       object
# geo           float64
# region         object
# dtype: object
# Unnamed: 0       0
# id               0
# text           224
# date             0
# retweets         0
# favorites        0
# mentions      6162
# hashtags      6288
# geo           6767
# region           0
# ...
